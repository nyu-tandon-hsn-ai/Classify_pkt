# %%
import pandas as pd

# %%
df_bili = pd.read_csv("./ddos_pkt_test_30%.csv")

# %%
###################
##  NORMAL DATA  ##
###################

# %%
# no upsampled normal data
# df_normal = pd.read_csv("/Users/tsaiflow/Desktop/NN&Sampling/data_upsampled_ddos(unb)_normal(own)/normal/no_upsampled/packet_rand_5__no_upsampling.csv")

# upsampled normal data
df_normal = pd.read_csv("/Users/tsaiflow/Desktop/NN&Sampling/data_upsampled_ddos(unb)_normal(own)/normal/upsampled/packet_rand_5__with_upsampling.csv")

#no sampled full data
# df_normal = pd.read_csv("/Users/tsaiflow/Desktop/NN&Sampling/data_upsampled_ddos(unb)_normal(own)/train_test_nosampled/test_nosampled_30%.csv")

# %%
## name of output
output = "/Users/tsaiflow/Desktop/NN&Sampling/data_upsampled_ddos(unb)_normal(own)/test/upsampled/test_normal_upsampled_5%_ddos_30%.csv"

# %%
df.head(5)
# Out:
#    Unnamed: 0   Flow Duration   Total Fwd Packets   Total Backward Packets  \
# 0      131366         2818924                   4                        0
# 1      107985        84751101                   8                        4
# 2      159621          160774                   3                        4
# 3       96270           10119                   3                        7
# 4      167934        99567941                   8                        4
#
#    Total Length of Fwd Packets   Total Length of Bwd Packets  \
# 0                           24                             0
# 1                           56                         11601
# 2                           26                         11607
# 3                           26                         11601
# 4                           56                         11601
#
#     Fwd Packet Length Max   Fwd Packet Length Min   Fwd Packet Length Mean  \
# ...

# %%
df = df.drop(df.columns[0], axis=1)

# %%
print("Read {} rows.".format(len(df)))
# Out:
# Read 12551 rows.

# %%
df = df[[' Flow Duration',
 ' Total Fwd Packets',
 ' Total Backward Packets',
 'Total Length of Fwd Packets',
 ' Total Length of Bwd Packets',
 ' Fwd Packet Length Max',
 ' Fwd Packet Length Min',
 ' Fwd Packet Length Mean',
 ' Fwd Packet Length Std',
 'Bwd Packet Length Max',
 ' Bwd Packet Length Min',
 ' Bwd Packet Length Mean',
 ' Bwd Packet Length Std',
 ' Min Packet Length',
 ' Max Packet Length',
 ' Packet Length Mean',
 ' Packet Length Std',
 'total pkt count',
 'total byte count',
 ' Label'
       ]]

# %%
# df.head(5)

# %%
df_normal.head(5)
# Out:
#    tcp.stream  avg(tcp_pkt_len)  stddev(tcp_pkt_len)  min(tcp_pkt_len)  \
# 0           0        955.880470           613.777080                 0
# 1           1       1459.692262            16.647668                 6
# 2           3        694.272269           625.756657                 0
# 3           4        329.230769           274.883658                 0
# 4           5        376.000000           301.220375                 0
#
#    max(tcp_pkt_len)   tot_pkt      tot_byte  rel_start   duration  \
# 0              1460   30620.0  2.926906e+07   0.000000  48.261553
# 1              1460  966340.0  1.410559e+09   0.000002  48.288029
# 2              1460   11900.0  8.261840e+06   6.821404  41.261432
# 3               648     260.0  8.560000e+04   9.805856  37.992407
# 4               648     160.0  6.016000e+04   7.797816  37.009245
#
#    avg(back_pkt_len)        ...          count(back_pkt)  count(forw_pkt)  \
# ...

# %%
# df2 = df_normal.columns.get_values()
# df2.tolist()

# %%
df_normal = df_normal.drop(['tcp.stream','rel_start'],axis=1)

# %%
df_normal.replace(
    -1.0, 0,
    inplace=True
)

# %%
df_normal = df_normal.fillna(0)

# %%
df_normal.insert(loc=19, column='outcome', value='normal')

# %%
df_normal.head(5)
# Out:
#    avg(tcp_pkt_len)  stddev(tcp_pkt_len)  min(tcp_pkt_len)  max(tcp_pkt_len)  \
# 0        955.880470           613.777080                 0              1460
# 1       1459.692262            16.647668                 6              1460
# 2        694.272269           625.756657                 0              1460
# 3        329.230769           274.883658                 0               648
# 4        376.000000           301.220375                 0               648
#
#     tot_pkt      tot_byte   duration  avg(back_pkt_len)  avg(forw_pkt_len)  \
# 0   30620.0  2.926906e+07  48.261553           0.000000         955.880470
# 1  966340.0  1.410559e+09  48.288029           0.000000        1459.692262
# 2   11900.0  8.261840e+06  41.261432        1227.304348         409.896907
# 3     260.0  8.560000e+04  37.992407         130.000000         648.000000
# 4     160.0  6.016000e+04  37.009245         104.000000         648.000000
#
# ...

# %%
print("Read {} rows.".format(len(df_normal)))
# Out:
# Read 7908 rows.

# %%
df_normal = df_normal[[
 'duration',
 'count(forw_pkt)',
 'count(back_pkt)',
 'sum(forw_pkt_len)',
 'sum(back_pkt_len)',
 'max(forw_pkt_len)',
 'min(forw_pkt_len)',
 'avg(forw_pkt_len)',
 'std(forw_pkt_len)',
 'max(back_pkt_len)',
 'min(back_pkt_len)',
 'avg(back_pkt_len)',
 'std(back_pkt_len)',
 'min(tcp_pkt_len)',
 'max(tcp_pkt_len)',
 'avg(tcp_pkt_len)',
 'stddev(tcp_pkt_len)',
 'tot_pkt',
 'tot_byte',
 'outcome']]

# %%
df_normal.head(5)
# Out:
#     duration  count(forw_pkt)  count(back_pkt)  sum(forw_pkt_len)  \
# 0  48.261553          30620.0              0.0       2.926906e+07
# 1  48.288029         966340.0              0.0       1.410559e+09
# 2  41.261432           7760.0           4140.0       3.180800e+06
# 3  37.992407            100.0            160.0       6.480000e+04
# 4  37.009245             80.0             80.0       5.184000e+04
#
#    sum(back_pkt_len)  max(forw_pkt_len)  min(forw_pkt_len)  avg(forw_pkt_len)  \
# 0                0.0             1460.0                0.0         955.880470
# 1                0.0             1460.0                6.0        1459.692262
# 2          5081040.0             1460.0                0.0         409.896907
# 3            20800.0              648.0              648.0         648.000000
# 4             8320.0              648.0              648.0         648.000000
#
#    std(forw_pkt_len)  max(back_pkt_len)  min(back_pkt_len)  avg(back_pkt_len)  \
# ...

# %%
df_normal.columns = [[' Flow Duration',
 ' Total Fwd Packets',
 ' Total Backward Packets',
 'Total Length of Fwd Packets',
 ' Total Length of Bwd Packets',
 ' Fwd Packet Length Max',
 ' Fwd Packet Length Min',
 ' Fwd Packet Length Mean',
 ' Fwd Packet Length Std',
 'Bwd Packet Length Max',
 ' Bwd Packet Length Min',
 ' Bwd Packet Length Mean',
 ' Bwd Packet Length Std',
 ' Min Packet Length',
 ' Max Packet Length',
 ' Packet Length Mean',
 ' Packet Length Std',
 'total pkt count',
 'total byte count',
 ' Label'
       ]]

# %%
df_1x = pd.concat([df, df_normal])

# %%
# df_1x.head(5)
print("Read {} rows.".format(len(df_1x)))
# Out:
# Read 20459 rows.

# %%
df_1x.head(5)
# Out:
#     Flow Duration   Total Fwd Packets   Total Backward Packets  \
# 0       2818924.0                 4.0                      0.0
# 1      84751101.0                 8.0                      4.0
# 2        160774.0                 3.0                      4.0
# 3         10119.0                 3.0                      7.0
# 4      99567941.0                 8.0                      4.0
#
#    Total Length of Fwd Packets   Total Length of Bwd Packets  \
# 0                         24.0                           0.0
# 1                         56.0                       11601.0
# 2                         26.0                       11607.0
# 3                         26.0                       11601.0
# 4                         56.0                       11601.0
#
#     Fwd Packet Length Max   Fwd Packet Length Min   Fwd Packet Length Mean  \
# 0                     6.0                     6.0                 6.000000
# ...

# %%
df_1x.to_csv(output)

# %%
# df_1x.to_csv('train_1x.csv')
